# %% [markdown]
# # Panama Canal Data Analysis
#
# This notebook explores the effects of ship size and lock type on water displacement, water loss, and operational cost in the Panama Canal. The analysis uses a custom Python module to simulate and quantify water usage metrics for different transit scenarios.

# %%
from src.canal_data import analyze_transit

# %%
import pandas as pd

# Define test ship sizes
ship_sizes = [10_000, 30_000, 50_000, 70_000]
lock_types = ["panamax", "neopanamax"]

# Collect results
results = []

for lock in lock_types:
    for size in ship_sizes:
        result = analyze_transit(ship_size=size, lock_type=lock)
        results.append(result)

# Convert to DataFrame
df = pd.DataFrame(results)
df.head()
# Out:
#     lock_type  ship_size  water_displaced  water_needed  water_lost  \
# 0     Panamax      10000          2400000      47600000  47600000.0
# 1     Panamax      30000          7200000      42800000  42800000.0
# 2     Panamax      50000         12000000      38000000  38000000.0
# 3     Panamax      70000         16800000      33200000  33200000.0
# 4  Neopanamax      10000          2400000      35600000  19580000.0
#
#    cost_per_lock  percent_savings  annual_water_displaced
# 0         9520.0         4.800000            201600000000
# 1         8560.0        14.400000            604800000000
# 2         7600.0        24.000000           1008000000000
# 3         6640.0        33.600000           1411200000000
# 4         7120.0         6.315789            201600000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid") # Set plot style

# Plot water lost per lock by ship size and lock type
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="ship_size", y="water_lost", hue="lock_type")

plt.title("Water Lost per Lock vs. Ship Size")
plt.xlabel("Ship Size (tons)")
plt.ylabel("Water Lost (gallons)")
plt.legend(title="Lock Type")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/nk/vwtp7n_53_18f4kxcylrscmm0000gn/T/ipykernel_22829/2155096687.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Lock Type")
